# %% [markdown]
# ### Setup
# ---

# %%
import boto3
from tipranks import TrClient,EtfScreener,ETFParams
import pandas as pd

# %%
ssm_client = boto3.client('ssm')
email = ssm_client.get_parameter(Name = '/side-hustle/tipranks/email')['Parameter']['Value']
password = ssm_client.get_parameter(Name = '/side-hustle/tipranks/password',WithDecryption=True)['Parameter']['Value']

# %%
client = TrClient(email,password)

# %%
screener = EtfScreener(client)
params = ETFParams()
screenerParams = params.screenerParams

# %%
matches = screener.screen(params)

# %%
tickers  = [data['ticker'] for data in matches['data']]

# %%
len(tickers)
# Out:
# 20

# %%
n = len(tickers)
index = list(range(n))
df = pd.DataFrame.from_records(matches['data'][0:n],index=list(range(n)))

# %%
df
# Out:
#    ticker stockType  stockTypeId sectorId  \
# 0     VOO       etf            5     None
# 1     SPY       etf            5     None
# 2     IVV       etf            5     None
# 3     VTI       etf            5     None
# 4     QQQ       etf            5     None
# 5     VEA       etf            5     None
# 6     VUG       etf            5     None
# 7     VTV       etf            5     None
# 8    IEFA       etf            5     None
# 9     BND       etf            5     None
# 10    AGG       etf            5     None
# 11  CSTNL       etf            5     None
# 12    IWF       etf            5     None
# 13  IRRRF       etf            5     None
# 14    IJH       etf            5     None
# 15    GLD       etf            5     None
# 16    VIG       etf            5     None
# 17   VXUS       etf            5     None
# 18    VWO       etf            5     None
# 19   IEMG       etf            5     None
#
#                                      analystConsensus  \
# 0   {'consensus': 'buy', 'rawConsensus': 4, 'distr...
# 1   {'consensus': 'buy', 'rawConsensus': 4, 'distr...
# 2   {'consensus': 'buy', 'rawConsensus': 4, 'distr...
# 3   {'consensus': 'buy', 'rawConsensus': 4, 'distr...
# 4   {'consensus': 'buy', 'rawConsensus': 4, 'distr...
# 5   {'consensus': 'buy', 'rawConsensus': 4, 'distr...
# 6   {'consensus': 'buy', 'rawConsensus': 4, 'distr...
# 7   {'consensus': 'buy', 'rawConsensus': 4, 'distr...
# 8   {'consensus': 'neutral', 'rawConsensus': 3, 'd...
# 9   {'consensus': None, 'rawConsensus': None, 'dis...
# 10  {'consensus': None, 'rawConsensus': None, 'dis...
# 11  {'consensus': 'buy', 'rawConsensus': 4, 'distr...
# 12  {'consensus': 'buy', 'rawConsensus': 4, 'distr...
# 13  {'consensus': 'buy', 'rawConsensus': 4, 'distr...
# 14  {'consensus': 'buy', 'rawConsensus': 4, 'distr...
# 15  {'consensus': None, 'rawConsensus': None, 'dis...
# 16  {'consensus': 'buy', 'rawConsensus': 4, 'distr...
# 17  {'consensus': None, 'rawConsensus': None, 'dis...
# 18  {'consensus': None, 'rawConsensus': None, 'dis...
# 19  {'consensus': None, 'rawConsensus': None, 'dis...
#
#                                  bestAnalystConsensus nextDividendDate  \
# 0   {'consensus': 'buy', 'rawConsensus': 4, 'distr...             None
# 1   {'consensus': 'buy', 'rawConsensus': 4, 'distr...             None
# 2   {'consensus': 'buy', 'rawConsensus': 4, 'distr...             None
# 3   {'consensus': 'buy', 'rawConsensus': 4, 'distr...             None
# 4   {'consensus': 'buy', 'rawConsensus': 4, 'distr...             None
# 5   {'consensus': 'buy', 'rawConsensus': 4, 'distr...             None
# 6   {'consensus': 'buy', 'rawConsensus': 4, 'distr...             None
# 7   {'consensus': 'buy', 'rawConsensus': 4, 'distr...             None
# 8   {'consensus': 'neutral', 'rawConsensus': 3, 'd...             None
# 9   {'consensus': None, 'rawConsensus': None, 'dis...             None
# 10  {'consensus': None, 'rawConsensus': None, 'dis...             None
# 11  {'consensus': 'buy', 'rawConsensus': 4, 'distr...             None
# 12  {'consensus': 'buy', 'rawConsensus': 4, 'distr...             None
# 13  {'consensus': 'buy', 'rawConsensus': 4, 'distr...             None
# 14  {'consensus': 'buy', 'rawConsensus': 4, 'distr...             None
# 15  {'consensus': None, 'rawConsensus': None, 'dis...             None
# 16  {'consensus': 'buy', 'rawConsensus': 4, 'distr...             None
# 17  {'consensus': None, 'rawConsensus': None, 'dis...             None
# 18  {'consensus': None, 'rawConsensus': None, 'dis...             None
# 19  {'consensus': None, 'rawConsensus': None, 'dis...             None
#
#    lastReportedEps nextEarningsReport stockUid  ... shouldAddLinkToStockPage  \
# 0             None               None     None  ...                     True
# 1             None               None     None  ...                     True
# 2             None               None     None  ...                     True
# 3             None               None     None  ...                     True
# 4             None               None     None  ...                     True
# 5             None               None     None  ...                     True
# 6             None               None     None  ...                     True
# 7             None               None     None  ...                     True
# 8             None               None     None  ...                     True
# 9             None               None     None  ...                     True
# 10            None               None     None  ...                     True
# 11            None               None     None  ...                     True
# 12            None               None     None  ...                     True
# 13            None               None     None  ...                     True
# 14            None               None     None  ...                     True
# 15            None               None     None  ...                     True
# 16            None               None     None  ...                     True
# 17            None               None     None  ...                     True
# 18            None               None     None  ...                     True
# 19            None               None     None  ...                     True
#
#     expenseRatio  marketCap marketCapCurrencyId newsSentiment landmarkPrices  \
# 0         0.0300       None                None             0           None
# 1         0.0945       None                None             0           None
# 2         0.0300       None                None             0           None
# 3         0.0300       None                None             0           None
# 4         0.2000       None                None             0           None
# 5         0.0300       None                None             0           None
# 6         0.0400       None                None             0           None
# 7         0.0400       None                None             0           None
# 8         0.0700       None                None             0           None
# 9         0.0300       None                None             0           None
# 10        0.0300       None                None             0           None
# 11        0.0700       None                None             0           None
# 12        0.1900       None                None             0           None
# 13        0.2000       None                None             0           None
# 14        0.0500       None                None             0           None
# 15        0.4000       None                None             0           None
# 16        0.0500       None                None             0           None
# 17        0.0500       None                None             0           None
# 18        0.0700       None                None             0           None
# 19        0.0900       None                None             0           None
#
#     priceTargetCurrencyId  marketCountryId  \
# 0                       1                1
# 1                       1                1
# 2                       1                1
# 3                       1                1
# 4                       1                1
# 5                       1                1
# 6                       1                1
# 7                       1                1
# 8                       1                1
# 9                       1                1
# 10                      1                1
# 11                      1                1
# 12                      1                1
# 13                      1                1
# 14                      1                1
# 15                      1                1
# 16                      1                1
# 17                      1                1
# 18                      1                1
# 19                      1                1
#
#                                   companyFullName stockCurrencyId
# 0                            Vanguard S&P 500 ETF               0
# 1                                   United States               0
# 2                        iShares Core S&P 500 ETF               0
# 3                         Van Ttl St MkId Shs ETF               0
# 4                               Invesco QQQ Trust               0
# 5             Vanguard FTSE Developed Markets ETF               0
# 6                     Vangrd Index Shs Growth ETF               0
# 7                          Vangrd Val Idx Shs ETF               0
# 8                      iShares Core MSCI EAFE ETF               0
# 9                                 Aggregate Bonds               0
# 10                                  USD Aggregate               0
# 11                 iShares Core S&P 500 UCITS ETF               0
# 12                                         Growth               0
# 13              iShares Core MSCI World UCITS ETF               0
# 14                                   Mid-Cap Core               0
# 15                                           Gold               0
# 16             Vanguard Dividend Appreciation ETF               0
# 17                        Vn Tl Int StkId Shs ETF               0
# 18  Van EmMk Stk Id Shs FTSE Emerging Markets ETF               0
# 19         iShares Core MSCI Emerging Markets ETF               0
#
# [20 rows x 32 columns]
